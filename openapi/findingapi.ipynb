# %%
# Z_g9mKXM9RkaRLHi_RRP
# aCQdGGtuM5

# %%
# 네이버 검색 API예제는 블로그를 비롯 전문자료까지 호출방법이 동일하므로 blog검색만 대표로 예제를 올렸습니다.
# 네이버 검색 Open API 예제 - 블로그 검색
import os
import sys
import urllib.request
client_id = "Z_g9mKXM9RkaRLHi_RRP"
client_secret = "aCQdGGtuM5"
# 검색어! 받기
encText = urllib.parse.quote("7급공채")
# url에 붙여서 query속성으로 검색어 보냄
url = "https://openapi.naver.com/v1/search/blog?query=" + encText # json 결과
# url = "https://openapi.naver.com/v1/search/blog.xml?query=" + encText # xml 결과
request = urllib.request.Request(url)
# 헤더에 클라이언트 아이디 비번 넣어야 함
request.add_header("X-Naver-Client-Id",client_id)
request.add_header("X-Naver-Client-Secret",client_secret)
response = urllib.request.urlopen(request)
rescode = response.getcode()
# 200일때가 검색 성공한 것
if(rescode==200):
    response_body = response.read()
    # 한글 변환
    print(response_body.decode('utf-8'))
    print(type(response_body))
else:
    print("Error Code:" + rescode)
# Out:
# {
# "lastBuildDate": "Sun, 05 Apr 2020 09:32:57 +0900",
# "total": 27308,
# "start": 1,
# "display": 10,
# "items": [
# {
# "title": "<b>7급</b> PSAT 준비, 5급 <b>공채</b> 합격생은 자료해석에 주목했다",
# "link": "https:\/\/blog.naver.com\/honaudo444?Redirect=Log&logNo=221860194692",
# "description": "국가직 7급 시험 PSAT 도입이 불과 1년밖에 남지 않았습니다. <b>7급 공채</b> 시험을 준비하는 수험생의 경우 많이 혼란스러우실 텐데요. PSAT 공부방법에 대해 5급 공채 합격생과 수험전문가들은 얼마나 많은... ",
# "bloggername": "이기자의 JOB NEWS",
# "bloggerlink": "https://blog.naver.com/honaudo444",
# "postdate": "20200319"
#
# },
# {
# "title": "지방직<b>7급 공채</b>로 일반행정직 공부하기!",
# "link": "https:\/\/blog.naver.com\/rni0823?Redirect=Log&logNo=221547639123",
# "description": "많지만 <b>7급공채</b>를 도전하는 것이 낫겠다 판단했어요. 국가직7급도 분명 도전할 수 있었지만 경쟁률이 높다는 이유로 조금 더 기피하게 되었고, 그리고 선발하는 인원도 매우 적은 편에 속해서 불합격 할 수 도... ",
# "bloggername": "푸르스름",
# "bloggerlink": "https://blog.naver.com/rni0823",
# "postdate": "20190527"
#
# },
# {
# "title": "대통령경호처 경호공무원 <b>7급 공채</b> 체크리스트!",
# "link": "https:\/\/blog.naver.com\/ctcxwiszlj?Redirect=Log&logNo=221554276782",
# "description": "오늘은 다름아닌 대통령경호처 경호공무원 <b>7급 공채</b>에 대해서 간단하게 소개를 가지도록 할... 선발분야 2019 경호공무원 <b>7급 공채</b>에서 올라온 바, 선발 분야는 두 가지로 구분이 되고 있습니다. 경호와... ",
# "bloggername": "니글니글 블로그",
# "bloggerlink": "https://blog.naver.com/ctcxwiszlj",
# "postdate": "20190604"
#
# },
# {
# "title": "국가직<b>7급</b> 일반행정직 시험과목 <b>공채</b>로 준비",
# "link": "https:\/\/blog.naver.com\/ca_bal?Redirect=Log&logNo=221633405061",
# "description": "국가직7급 일반행정직 시험과목 공채로 준비 여러분들이 선호하는 직장의 기준은 무엇일까요? 아마... 생각한다면 <b>7급공채</b>를 준비하는 것이 생각보다 힘들 수 있겠다 싶었지만 애초에 지방직과 국가직 중... ",
# "bloggername": "MEMORY",
# "bloggerlink": "https://blog.naver.com/ca_bal",
# "postdate": "20190830"
#
# },
# {
# "title": "2021 <b>7급</b> 공무원 <b>공채</b>  PSAT 문제  +  시험과목 변동사항",
# "link": "https:\/\/blog.naver.com\/mtpel?Redirect=Log&logNo=221816015828",
# "description": "2021년 7급 공무원 공채 시험과목 변동사항 <b>7급공채</b> 1차 시험과목 ~2020년 국어/영어/한국사 ▼ 2020년~ 언어논리/자료해석/상황판단영력 <b>7급공채</b> 2차 시험과목 헌법/행정법/행정학/경제학 (기존과 동일)... ",
# "bloggername": "오서방♥내서방",
# "bloggerlink": "https://blog.naver.com/mtpel",
# "postdate": "20200219"
#
# },
# {
# "title": "<b>7급</b> 국가 공무원 <b>공채</b> 필기 과목 2021년 PSAT 도입 개편",
# "link": "https:\/\/blog.naver.com\/ktv520?Redirect=Log&logNo=221347303682",
# "description": "2021년 <b>7급 공채</b> 필기 과목 개편 다가오는 2021년부터 국가공무원 <b>7급 공채</b> 필기시험에서 기존 국어... PSAT는 2004년 5급 외무 공채에 처음 도입되어 현재 5급 공채, 외교관 후보자 선발시험, 5급, 7급... ",
# "bloggername": "KTV 국민방송",
# "bloggerlink": "https://blog.naver.com/ktv520",
# "postdate": "20180828"
#
# },
# {
# "title": "<b>7급</b> 서울시 공무원 <b>공채</b> 경쟁률 합격선 체크 2019년 대비",
# "link": "https:\/\/blog.naver.com\/affa3366?Redirect=Log&logNo=221379291685",
# "description": "2019년 서울시 공무원 시험에서 예상 변경내용이 있다면, 예년 6월 경에 별도로 시행되던 공채 필기시험이 7급은 지방직 <b>7급 공채</b>와 필기시험을 같은날로 조정한다는 보도가 이어지고 있으므로 변화하는... ",
# "bloggername": "에듀피디자격증공식블로그",
# "bloggerlink": "https://blog.naver.com/affa3366",
# "postdate": "20181017"
#
# },
# {
# "title": "[사람나래] <b>7급 공채</b>, 공직적격성평가(PSAT) 도입에 거는 기대",
# "link": "https:\/\/blog.naver.com\/mirae_saram?Redirect=Log&logNo=221345134451",
# "description": "<b>7급 공채</b> 1차 필기시험에 국어 대신 '공직적격성평가(PSAT)'가 도입되고, 한국사는 국사편찬위원회의... 5급 공채, 지역인재 추천채용제, 5급 민간경력자 일괄채용 시험, 외교관 후보자 선발시험, 7급... ",
# "bloggername": "대한민국 인사혁신처",
# "bloggerlink": "https://blog.naver.com/mirae_saram",
# "postdate": "20180824"
#
# },
# {
# "title": "2020 국가직 <b>7급</b> 공무원 <b>공채</b> 직렬 별 선발인원 영어 평가 기준",
# "link": "https:\/\/blog.naver.com\/eejj6090?Redirect=Log&logNo=221765230786",
# "description": "2020 국가직 7급 공무원 공채 직렬 별 선발인원 시험일정 및 과목 영어 평가 기준 안녕하세요! 다가오는 2020년 국가직 7급공무원 공개경쟁채용 선발인원 그리고 국가직 <b>7급 공채</b>의 경우 영어 평가방법이... ",
# "bloggername": "꾸래꿍's",
# "bloggerlink": "https://blog.naver.com/eejj6090",
# "postdate": "20200109"
#
# },
# {
# "title": "국가직<b>7급 공채</b> 7급공무원시험학원에서 언급한 과목!",
# "link": "https:\/\/blog.naver.com\/ytnam3?Redirect=Log&logNo=221743887028",
# "description": "공시에 대한 모든 이슈를 집약 해 놓았다 보니 정보에 대해서 서툴지언정, 금방 시험의 흐름을 파악하고 나서 교과서로 국가직<b>7급 공채</b> 시험 공부를 시작할수 있습니다! 7급공무원시험학원에서도 손 쉽게... ",
# "bloggername": "에듀윌 공무원 공식블로그",
# "bloggerlink": "https://blog.naver.com/ytnam3",
# "postdate": "20191220"
#
# }
# ]
# }
#
# <class 'bytes'>
