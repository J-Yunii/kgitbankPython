# %%
# %matplotlib inline
import urllib.request
import json, datetime, time
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib as mpl
import warnings

# %%
url = f"http://www.kobis.or.kr/kobisopenapi/webservice/rest/boxoffice/searchDailyBoxOfficeList.json?key=89b19113e79475b9667a198742fcf7f6&targetDt=20200404"
response = urllib.request.urlopen(url)
responseData = response.read()
print(response.read())
# Out:
# b''

# %%
result = json.loads(responseData)
print(result)
print(type(result))
# Out:
# {'boxOfficeResult': {'boxofficeType': '일별 박스오피스', 'showRange': '20200404~20200404', 'dailyBoxOfficeList': [{'rnum': '1', 'rank': '1', 'rankInten': '0', 'rankOldAndNew': 'OLD', 'movieCd': '20205262', 'movieNm': '엽문4: 더 파이널', 'openDt': '2020-04-01', 'salesAmt': '75121500', 'salesShare': '20.0', 'salesInten': '37409400', 'salesChange': '99.2', 'salesAcc': '199644200', 'audiCnt': '8288', 'audiInten': '4007', 'audiChange': '93.6', 'audiAcc': '23533', 'scrnCnt': '199', 'showCnt': '618'}, {'rnum': '2', 'rank': '2', 'rankInten': '1', 'rankOldAndNew': 'OLD', 'movieCd': '20192399', 'movieNm': '1917', 'openDt': '2020-02-19', 'salesAmt': '51816600', 'salesShare': '13.8', 'salesInten': '27695280', 'salesChange': '114.8', 'salesAcc': '6645285440', 'audiCnt': '5683', 'audiInten': '2899', 'audiChange': '104.1', 'audiAcc': '729732', 'scrnCnt': '362', 'showCnt': '638'}, {'rnum': '3', 'rank': '3', 'rankInten': '-1', 'rankOldAndNew': 'OLD', 'movieCd': '20204107', 'movieNm': '주디', 'openDt': '2020-03-25', 'salesAmt': '44614800', 'salesShare': '11.9', 'salesInten': '19833300', 'salesChange': '80', 'salesAcc': '536048320', 'audiCnt': '5010', 'audiInten': '2109', 'audiChange': '72.7', 'audiAcc': '66420', 'scrnCnt': '352', 'showCnt': '718'}, {'rnum': '4', 'rank': '4', 'rankInten': '1', 'rankOldAndNew': 'OLD', 'movieCd': '20199842', 'movieNm': '인비저블맨', 'openDt': '2020-02-26', 'salesAmt': '32247140', 'salesShare': '8.6', 'salesInten': '16899580', 'salesChange': '110.1', 'salesAcc': '4811744180', 'audiCnt': '3453', 'audiInten': '1760', 'audiChange': '104', 'audiAcc': '552161', 'scrnCnt': '280', 'showCnt': '497'}, {'rnum': '5', 'rank': '5', 'rankInten': '1', 'rankOldAndNew': 'OLD', 'movieCd': '20206446', 'movieNm': 'n번째 이별 중', 'openDt': '2020-04-01', 'salesAmt': '27768800', 'salesShare': '7.4', 'salesInten': '15020600', 'salesChange': '117.8', 'salesAcc': '69091500', 'audiCnt': '2906', 'audiInten': '1517', 'audiChange': '109.2', 'audiAcc': '7783', 'scrnCnt': '171', 'showCnt': '396'}, {'rnum': '6', 'rank': '6', 'rankInten': '-2', 'rankOldAndNew': 'OLD', 'movieCd': '20205841', 'movieNm': '더 터닝 ', 'openDt': '2020-04-02', 'salesAmt': '26260580', 'salesShare': '7.0', 'salesInten': '8870320', 'salesChange': '51', 'salesAcc': '67383420', 'audiCnt': '2843', 'audiInten': '887', 'audiChange': '45.3', 'audiAcc': '7653', 'scrnCnt': '294', 'showCnt': '549'}, {'rnum': '7', 'rank': '7', 'rankInten': '0', 'rankOldAndNew': 'OLD', 'movieCd': '20205708', 'movieNm': '스케어리 스토리:어둠의 속삭임 ', 'openDt': '2020-03-25', 'salesAmt': '18317220', 'salesShare': '4.9', 'salesInten': '8036980', 'salesChange': '78.2', 'salesAcc': '302232640', 'audiCnt': '1947', 'audiInten': '816', 'audiChange': '72.1', 'audiAcc': '36284', 'scrnCnt': '207', 'showCnt': '376'}, {'rnum': '8', 'rank': '8', 'rankInten': '0', 'rankOldAndNew': 'OLD', 'movieCd': '20167904', 'movieNm': '라라랜드', 'openDt': '2016-12-07', 'salesAmt': '14496240', 'salesShare': '3.9', 'salesInten': '6158900', 'salesChange': '73.9', 'salesAcc': '30277354808', 'audiCnt': '1618', 'audiInten': '658', 'audiChange': '68.5', 'audiAcc': '3631486', 'scrnCnt': '89', 'showCnt': '196'}, {'rnum': '9', 'rank': '9', 'rankInten': '1', 'rankOldAndNew': 'OLD', 'movieCd': '20204791', 'movieNm': '다크 워터스 ', 'openDt': '2020-03-11', 'salesAmt': '6257460', 'salesShare': '1.7', 'salesInten': '3069160', 'salesChange': '96.3', 'salesAcc': '1078757380', 'audiCnt': '721', 'audiInten': '350', 'audiChange': '94.3', 'audiAcc': '125149', 'scrnCnt': '119', 'showCnt': '150'}, {'rnum': '10', 'rank': '10', 'rankInten': '4', 'rankOldAndNew': 'OLD', 'movieCd': '20010013', 'movieNm': '봄날은 간다', 'openDt': '2001-09-28', 'salesAmt': '2952000', 'salesShare': '0.8', 'salesInten': '1337000', 'salesChange': '82.8', 'salesAcc': '43191500', 'audiCnt': '551', 'audiInten': '228', 'audiChange': '70.6', 'audiAcc': '7482', 'scrnCnt': '46', 'showCnt': '77'}]}}
# <class 'dict'>

# %%
pre_result = result["boxOfficeResult"]["dailyBoxOfficeList"]
print(pre_result)
# Out:
# [{'rnum': '1', 'rank': '1', 'rankInten': '0', 'rankOldAndNew': 'OLD', 'movieCd': '20205262', 'movieNm': '엽문4: 더 파이널', 'openDt': '2020-04-01', 'salesAmt': '75121500', 'salesShare': '20.0', 'salesInten': '37409400', 'salesChange': '99.2', 'salesAcc': '199644200', 'audiCnt': '8288', 'audiInten': '4007', 'audiChange': '93.6', 'audiAcc': '23533', 'scrnCnt': '199', 'showCnt': '618'}, {'rnum': '2', 'rank': '2', 'rankInten': '1', 'rankOldAndNew': 'OLD', 'movieCd': '20192399', 'movieNm': '1917', 'openDt': '2020-02-19', 'salesAmt': '51816600', 'salesShare': '13.8', 'salesInten': '27695280', 'salesChange': '114.8', 'salesAcc': '6645285440', 'audiCnt': '5683', 'audiInten': '2899', 'audiChange': '104.1', 'audiAcc': '729732', 'scrnCnt': '362', 'showCnt': '638'}, {'rnum': '3', 'rank': '3', 'rankInten': '-1', 'rankOldAndNew': 'OLD', 'movieCd': '20204107', 'movieNm': '주디', 'openDt': '2020-03-25', 'salesAmt': '44614800', 'salesShare': '11.9', 'salesInten': '19833300', 'salesChange': '80', 'salesAcc': '536048320', 'audiCnt': '5010', 'audiInten': '2109', 'audiChange': '72.7', 'audiAcc': '66420', 'scrnCnt': '352', 'showCnt': '718'}, {'rnum': '4', 'rank': '4', 'rankInten': '1', 'rankOldAndNew': 'OLD', 'movieCd': '20199842', 'movieNm': '인비저블맨', 'openDt': '2020-02-26', 'salesAmt': '32247140', 'salesShare': '8.6', 'salesInten': '16899580', 'salesChange': '110.1', 'salesAcc': '4811744180', 'audiCnt': '3453', 'audiInten': '1760', 'audiChange': '104', 'audiAcc': '552161', 'scrnCnt': '280', 'showCnt': '497'}, {'rnum': '5', 'rank': '5', 'rankInten': '1', 'rankOldAndNew': 'OLD', 'movieCd': '20206446', 'movieNm': 'n번째 이별 중', 'openDt': '2020-04-01', 'salesAmt': '27768800', 'salesShare': '7.4', 'salesInten': '15020600', 'salesChange': '117.8', 'salesAcc': '69091500', 'audiCnt': '2906', 'audiInten': '1517', 'audiChange': '109.2', 'audiAcc': '7783', 'scrnCnt': '171', 'showCnt': '396'}, {'rnum': '6', 'rank': '6', 'rankInten': '-2', 'rankOldAndNew': 'OLD', 'movieCd': '20205841', 'movieNm': '더 터닝 ', 'openDt': '2020-04-02', 'salesAmt': '26260580', 'salesShare': '7.0', 'salesInten': '8870320', 'salesChange': '51', 'salesAcc': '67383420', 'audiCnt': '2843', 'audiInten': '887', 'audiChange': '45.3', 'audiAcc': '7653', 'scrnCnt': '294', 'showCnt': '549'}, {'rnum': '7', 'rank': '7', 'rankInten': '0', 'rankOldAndNew': 'OLD', 'movieCd': '20205708', 'movieNm': '스케어리 스토리:어둠의 속삭임 ', 'openDt': '2020-03-25', 'salesAmt': '18317220', 'salesShare': '4.9', 'salesInten': '8036980', 'salesChange': '78.2', 'salesAcc': '302232640', 'audiCnt': '1947', 'audiInten': '816', 'audiChange': '72.1', 'audiAcc': '36284', 'scrnCnt': '207', 'showCnt': '376'}, {'rnum': '8', 'rank': '8', 'rankInten': '0', 'rankOldAndNew': 'OLD', 'movieCd': '20167904', 'movieNm': '라라랜드', 'openDt': '2016-12-07', 'salesAmt': '14496240', 'salesShare': '3.9', 'salesInten': '6158900', 'salesChange': '73.9', 'salesAcc': '30277354808', 'audiCnt': '1618', 'audiInten': '658', 'audiChange': '68.5', 'audiAcc': '3631486', 'scrnCnt': '89', 'showCnt': '196'}, {'rnum': '9', 'rank': '9', 'rankInten': '1', 'rankOldAndNew': 'OLD', 'movieCd': '20204791', 'movieNm': '다크 워터스 ', 'openDt': '2020-03-11', 'salesAmt': '6257460', 'salesShare': '1.7', 'salesInten': '3069160', 'salesChange': '96.3', 'salesAcc': '1078757380', 'audiCnt': '721', 'audiInten': '350', 'audiChange': '94.3', 'audiAcc': '125149', 'scrnCnt': '119', 'showCnt': '150'}, {'rnum': '10', 'rank': '10', 'rankInten': '4', 'rankOldAndNew': 'OLD', 'movieCd': '20010013', 'movieNm': '봄날은 간다', 'openDt': '2001-09-28', 'salesAmt': '2952000', 'salesShare': '0.8', 'salesInten': '1337000', 'salesChange': '82.8', 'salesAcc': '43191500', 'audiCnt': '551', 'audiInten': '228', 'audiChange': '70.6', 'audiAcc': '7482', 'scrnCnt': '46', 'showCnt': '77'}]

# %%
cine=[]
for i in range(0,len(pre_result)):
        pre_result[i]['targetDt']='20200404'
        cine.append(pre_result[i])
print(cine)
# Out:
# [{'rnum': '1', 'rank': '1', 'rankInten': '0', 'rankOldAndNew': 'OLD', 'movieCd': '20205262', 'movieNm': '엽문4: 더 파이널', 'openDt': '2020-04-01', 'salesAmt': '75121500', 'salesShare': '20.0', 'salesInten': '37409400', 'salesChange': '99.2', 'salesAcc': '199644200', 'audiCnt': '8288', 'audiInten': '4007', 'audiChange': '93.6', 'audiAcc': '23533', 'scrnCnt': '199', 'showCnt': '618', 'targetDt': '20200404'}, {'rnum': '2', 'rank': '2', 'rankInten': '1', 'rankOldAndNew': 'OLD', 'movieCd': '20192399', 'movieNm': '1917', 'openDt': '2020-02-19', 'salesAmt': '51816600', 'salesShare': '13.8', 'salesInten': '27695280', 'salesChange': '114.8', 'salesAcc': '6645285440', 'audiCnt': '5683', 'audiInten': '2899', 'audiChange': '104.1', 'audiAcc': '729732', 'scrnCnt': '362', 'showCnt': '638', 'targetDt': '20200404'}, {'rnum': '3', 'rank': '3', 'rankInten': '-1', 'rankOldAndNew': 'OLD', 'movieCd': '20204107', 'movieNm': '주디', 'openDt': '2020-03-25', 'salesAmt': '44614800', 'salesShare': '11.9', 'salesInten': '19833300', 'salesChange': '80', 'salesAcc': '536048320', 'audiCnt': '5010', 'audiInten': '2109', 'audiChange': '72.7', 'audiAcc': '66420', 'scrnCnt': '352', 'showCnt': '718', 'targetDt': '20200404'}, {'rnum': '4', 'rank': '4', 'rankInten': '1', 'rankOldAndNew': 'OLD', 'movieCd': '20199842', 'movieNm': '인비저블맨', 'openDt': '2020-02-26', 'salesAmt': '32247140', 'salesShare': '8.6', 'salesInten': '16899580', 'salesChange': '110.1', 'salesAcc': '4811744180', 'audiCnt': '3453', 'audiInten': '1760', 'audiChange': '104', 'audiAcc': '552161', 'scrnCnt': '280', 'showCnt': '497', 'targetDt': '20200404'}, {'rnum': '5', 'rank': '5', 'rankInten': '1', 'rankOldAndNew': 'OLD', 'movieCd': '20206446', 'movieNm': 'n번째 이별 중', 'openDt': '2020-04-01', 'salesAmt': '27768800', 'salesShare': '7.4', 'salesInten': '15020600', 'salesChange': '117.8', 'salesAcc': '69091500', 'audiCnt': '2906', 'audiInten': '1517', 'audiChange': '109.2', 'audiAcc': '7783', 'scrnCnt': '171', 'showCnt': '396', 'targetDt': '20200404'}, {'rnum': '6', 'rank': '6', 'rankInten': '-2', 'rankOldAndNew': 'OLD', 'movieCd': '20205841', 'movieNm': '더 터닝 ', 'openDt': '2020-04-02', 'salesAmt': '26260580', 'salesShare': '7.0', 'salesInten': '8870320', 'salesChange': '51', 'salesAcc': '67383420', 'audiCnt': '2843', 'audiInten': '887', 'audiChange': '45.3', 'audiAcc': '7653', 'scrnCnt': '294', 'showCnt': '549', 'targetDt': '20200404'}, {'rnum': '7', 'rank': '7', 'rankInten': '0', 'rankOldAndNew': 'OLD', 'movieCd': '20205708', 'movieNm': '스케어리 스토리:어둠의 속삭임 ', 'openDt': '2020-03-25', 'salesAmt': '18317220', 'salesShare': '4.9', 'salesInten': '8036980', 'salesChange': '78.2', 'salesAcc': '302232640', 'audiCnt': '1947', 'audiInten': '816', 'audiChange': '72.1', 'audiAcc': '36284', 'scrnCnt': '207', 'showCnt': '376', 'targetDt': '20200404'}, {'rnum': '8', 'rank': '8', 'rankInten': '0', 'rankOldAndNew': 'OLD', 'movieCd': '20167904', 'movieNm': '라라랜드', 'openDt': '2016-12-07', 'salesAmt': '14496240', 'salesShare': '3.9', 'salesInten': '6158900', 'salesChange': '73.9', 'salesAcc': '30277354808', 'audiCnt': '1618', 'audiInten': '658', 'audiChange': '68.5', 'audiAcc': '3631486', 'scrnCnt': '89', 'showCnt': '196', 'targetDt': '20200404'}, {'rnum': '9', 'rank': '9', 'rankInten': '1', 'rankOldAndNew': 'OLD', 'movieCd': '20204791', 'movieNm': '다크 워터스 ', 'openDt': '2020-03-11', 'salesAmt': '6257460', 'salesShare': '1.7', 'salesInten': '3069160', 'salesChange': '96.3', 'salesAcc': '1078757380', 'audiCnt': '721', 'audiInten': '350', 'audiChange': '94.3', 'audiAcc': '125149', 'scrnCnt': '119', 'showCnt': '150', 'targetDt': '20200404'}, {'rnum': '10', 'rank': '10', 'rankInten': '4', 'rankOldAndNew': 'OLD', 'movieCd': '20010013', 'movieNm': '봄날은 간다', 'openDt': '2001-09-28', 'salesAmt': '2952000', 'salesShare': '0.8', 'salesInten': '1337000', 'salesChange': '82.8', 'salesAcc': '43191500', 'audiCnt': '551', 'audiInten': '228', 'audiChange': '70.6', 'audiAcc': '7482', 'scrnCnt': '46', 'showCnt': '77', 'targetDt': '20200404'}]

# %%
dataframe=pd.DataFrame(cine)
print(dataframe.columns)
# Out:
# Index(['rnum', 'rank', 'rankInten', 'rankOldAndNew', 'movieCd', 'movieNm',
#        'openDt', 'salesAmt', 'salesShare', 'salesInten', 'salesChange',
#        'salesAcc', 'audiCnt', 'audiInten', 'audiChange', 'audiAcc', 'scrnCnt',
#        'showCnt', 'targetDt'],
#       dtype='object')

# %%
dataframe
# Out:
#   rnum rank rankInten rankOldAndNew   movieCd            movieNm      openDt  \
# 0    1    1         0           OLD  20205262         엽문4: 더 파이널  2020-04-01
# 1    2    2         1           OLD  20192399               1917  2020-02-19
# 2    3    3        -1           OLD  20204107                 주디  2020-03-25
# 3    4    4         1           OLD  20199842              인비저블맨  2020-02-26
# 4    5    5         1           OLD  20206446           n번째 이별 중  2020-04-01
# 5    6    6        -2           OLD  20205841              더 터닝   2020-04-02
# 6    7    7         0           OLD  20205708  스케어리 스토리:어둠의 속삭임   2020-03-25
# 7    8    8         0           OLD  20167904               라라랜드  2016-12-07
# 8    9    9         1           OLD  20204791            다크 워터스   2020-03-11
# 9   10   10         4           OLD  20010013             봄날은 간다  2001-09-28
#
#    salesAmt salesShare salesInten salesChange     salesAcc audiCnt audiInten  \
# 0  75121500       20.0   37409400        99.2    199644200    8288      4007
# 1  51816600       13.8   27695280       114.8   6645285440    5683      2899
# 2  44614800       11.9   19833300          80    536048320    5010      2109
# 3  32247140        8.6   16899580       110.1   4811744180    3453      1760
# 4  27768800        7.4   15020600       117.8     69091500    2906      1517
# 5  26260580        7.0    8870320          51     67383420    2843       887
# 6  18317220        4.9    8036980        78.2    302232640    1947       816
# 7  14496240        3.9    6158900        73.9  30277354808    1618       658
# 8   6257460        1.7    3069160        96.3   1078757380     721       350
# 9   2952000        0.8    1337000        82.8     43191500     551       228
#
#   audiChange  audiAcc scrnCnt showCnt  targetDt
# 0       93.6    23533     199     618  20200404
# 1      104.1   729732     362     638  20200404
# 2       72.7    66420     352     718  20200404
# 3        104   552161     280     497  20200404
# 4      109.2     7783     171     396  20200404
# 5       45.3     7653     294     549  20200404
# 6       72.1    36284     207     376  20200404
# 7       68.5  3631486      89     196  20200404
# 8       94.3   125149     119     150  20200404
# 9       70.6     7482      46      77  20200404

# %%
print(time.time())
print(time.localtime(time.time()))
movieDate=time.strftime('%Y%m%d', time.localtime(time.time()))
movieDate
# Out:
# 1586056287.012106
# time.struct_time(tm_year=2020, tm_mon=4, tm_mday=5, tm_hour=12, tm_min=11, tm_sec=27, tm_wday=6, tm_yday=96, tm_isdst=0)
# '20200405'

# %%
datetime_obj = datetime.datetime.strptime(movieDate,"%Y%m%d").date()
print(datetime_obj)
# Out:
# 2020-04-05

# %%
datetime_obj_tmp = datetime_obj - datetime.timedelta(days=1)  #weeks=1
datetime_obj_tmp
# Out:
# datetime.date(2020, 4, 4)

# %%
def cineInfo(movieCd):
    url = f"http://www.kobis.or.kr/kobisopenapi/webservice/rest/boxoffice/searchDailyBoxOfficeList.json?key=89b19113e79475b9667a198742fcf7f6&targetDt=20200404movieCd="+str(movieCd)
    response = urllib.request.urlopen(url)
    text = response.read()
    #print(text)
    d = json.loads(text)
    #print(d)
    movieInfo = d['movieInfoResult']['movieInfo']
    return movieInfo

# %%
movieInfo=cineInfo(20204107)
movieInfo
print(movieInfo['movieCd'],
      movieInfo['movieNm'],
      movieInfo['showTm'],
      len(movieInfo['actors']),
      len(movieInfo['showTypes']))
# Out:
# KeyErrorTraceback (most recent call last)
# <ipython-input-81-97f2597235bd> in <module>
# ----> 1 movieInfo=cineInfo(20204107)
#       2 movieInfo
#       3 print(movieInfo['movieCd'],
#       4       movieInfo['movieNm'],
#       5       movieInfo['showTm'],
#
# <ipython-input-80-df60b9c0dab8> in cineInfo(movieCd)
#       6     d = json.loads(text)
#       7     #print(d)
# ----> 8     movieInfo = d['movieInfoResult']['movieInfo']
#       9     return movieInfo
#
# KeyError: 'movieInfoResult'

# %%
# 필요한 영화 코드
df = pd.read_csv(r'cinebox.csv',engine='python',encoding='utf-8')
codeitem = pd.unique(df['movieCd'])
print(codeitem)
print(type(codeitem))

codeitem = pd.unique(df['movieCd']).tolist()
print(codeitem)
print(type(codeitem))
# Out:
# [20199842 20192399 20204791 20193321 20180962 20192240 20180523 19980231
#  20205096 20135428 20167542 20204340 20010238 20192751 19940116 20184574
#  20204681 20196828 20040598 20205529 20190864 20193526 20197390 20183782
#  20204546 20182447 20205525 20181434 20193911 20184891 20180939]
# <class 'numpy.ndarray'>
# [20199842, 20192399, 20204791, 20193321, 20180962, 20192240, 20180523, 19980231, 20205096, 20135428, 20167542, 20204340, 20010238, 20192751, 19940116, 20184574, 20204681, 20196828, 20040598, 20205529, 20190864, 20193526, 20197390, 20183782, 20204546, 20182447, 20205525, 20181434, 20193911, 20184891, 20180939]
# <class 'list'>

# %%
cine=[]
for code in codeitem:
    movieInfo = cineInfo(code)
    item={'movieCd':movieInfo['movieCd'],'movieNm':movieInfo['movieNm'],'showTm':movieInfo['showTm'],'actors':len(movieInfo['actors']),'showTypes':len(movieInfo['showTypes'])}
    cine.append(item)

dataframe=pd.DataFrame(cine)
dataframe.to_csv("cine.csv",index = False)
# Out:
# KeyErrorTraceback (most recent call last)
# <ipython-input-83-987787c8bb8e> in <module>
#       1 cine=[]
#       2 for code in codeitem:
# ----> 3     movieInfo = cineInfo(code)
#       4     item={'movieCd':movieInfo['movieCd'],'movieNm':movieInfo['movieNm'],'showTm':movieInfo['showTm'],'actors':len(movieInfo['actors']),'showTypes':len(movieInfo['showTypes'])}
#       5     cine.append(item)
#
# <ipython-input-80-df60b9c0dab8> in cineInfo(movieCd)
#       6     d = json.loads(text)
#       7     #print(d)
# ----> 8     movieInfo = d['movieInfoResult']['movieInfo']
#       9     return movieInfo
#
# KeyError: 'movieInfoResult'

# %%
def graph_m(title):
    df = pd.read_csv(r'cinebox.csv',engine='python',encoding='utf-8')
    df=df.drop('rnum',axis=1)  # 불러온 컬럼중 제거할 컬럼이 있다면 제거한다.
    print(title)
    print(df.columns)
    print(df.head())
    temp = df[df['movieNm'] == title]
    print(temp[['salesAmt','targetDt','movieNm']])
    print(temp.dtypes)
    mpl.rc('font', family='NanumBarunGothic') #한글 폰트 설정
    plt.bar(temp['targetDt'].astype(str),temp['salesAmt']) 
    plt.title('일별 매출액 막대 그래프')
    plt.xlabel('날짜')
    plt.ylabel('총매출액')
    plt.xticks(fontsize=10, rotation=90)
    # 만들어진 그래프 저장
    url1="" + title + ".png"
    plt.savefig(url1)

if __name__ == "__main__":
    graph_m("다크 워터스")
# Out:
# 다크 워터스
# Index(['rank', 'rankInten', 'rankOldAndNew', 'movieCd', 'movieNm', 'openDt',
#        'salesAmt', 'salesShare', 'salesInten', 'salesChange', 'salesAcc',
#        'audiCnt', 'audiInten', 'audiChange', 'audiAcc', 'scrnCnt', 'showCnt',
#        'targetDt'],
#       dtype='object')
#    rank  rankInten rankOldAndNew   movieCd           movieNm      openDt  \
# 0     1          0           OLD  20199842             인비저블맨  2020-02-26
# 1     2          0           OLD  20192399              1917  2020-02-19
# 2     3          0           OLD  20204791           다크 워터스   2020-03-11
# 3     4          0           OLD  20193321            정직한 후보  2020-02-12
# 4     5          0           OLD  20180962  지푸라기라도 잡고 싶은 짐승들  2020-02-19
#
#    salesAmt  salesShare  salesInten  salesChange     salesAcc  audiCnt  \
# 0  43585380        22.3    -5891160        -11.9   4409430520     5210
# 1  40711640        20.8      716600          1.8   6197474320     4775
# 2  19967840        10.2      748680          3.9    943203760     2460
# 3   7572620         3.9     -391480         -4.9  12756431310     1297
# 4   9365900         4.8      821820          9.6   5331424090     1156
#
#    audiInten  audiChange  audiAcc  scrnCnt  showCnt  targetDt
# 0       -694       -11.8   504363      483     1130  20200324
# 1        104         2.2   676039      489     1024  20200324
# 2        111         4.7   108239      404      790  20200324
# 3        -16        -1.2  1523417      238      390  20200324
# 4        132        12.9   614216      236      374  20200324
# Empty DataFrame
# Columns: [salesAmt, targetDt, movieNm]
# Index: []
# rank               int64
# rankInten          int64
# rankOldAndNew     object
# movieCd            int64
# movieNm           object
# openDt            object
# salesAmt           int64
# salesShare       float64
# salesInten         int64
# salesChange      float64
# salesAcc           int64
# audiCnt            int64
# audiInten          int64
# audiChange       float64
# audiAcc            int64
# scrnCnt            int64
# showCnt            int64
# targetDt           int64
# dtype: object

# %%
df = pd.read_csv(r'cinebox.csv',engine='python',encoding='utf-8')
df.head()
# Out:
#    rnum  rank  rankInten rankOldAndNew   movieCd           movieNm  \
# 0     1     1          0           OLD  20199842             인비저블맨
# 1     2     2          0           OLD  20192399              1917
# 2     3     3          0           OLD  20204791           다크 워터스
# 3     4     4          0           OLD  20193321            정직한 후보
# 4     5     5          0           OLD  20180962  지푸라기라도 잡고 싶은 짐승들
#
#        openDt  salesAmt  salesShare  salesInten  salesChange     salesAcc  \
# 0  2020-02-26  43585380        22.3    -5891160        -11.9   4409430520
# 1  2020-02-19  40711640        20.8      716600          1.8   6197474320
# 2  2020-03-11  19967840        10.2      748680          3.9    943203760
# 3  2020-02-12   7572620         3.9     -391480         -4.9  12756431310
# 4  2020-02-19   9365900         4.8      821820          9.6   5331424090
#
#    audiCnt  audiInten  audiChange  audiAcc  scrnCnt  showCnt  targetDt
# 0     5210       -694       -11.8   504363      483     1130  20200324
# 1     4775        104         2.2   676039      489     1024  20200324
# 2     2460        111         4.7   108239      404      790  20200324
# 3     1297        -16        -1.2  1523417      238      390  20200324
# 4     1156        132        12.9   614216      236      374  20200324

# %%
df['movieNm'] == '1917'
# Out:
# 0      False
# 1       True
# 2      False
# 3      False
# 4      False
#        ...
# 295    False
# 296    False
# 297    False
# 298    False
# 299    False
# Name: movieNm, Length: 300, dtype: bool

# %%
# true인 것만 가져온다.
temp1 = df[df['movieNm'] == '1917']

# %%
temp1.head()
# Out:
#     rnum  rank  rankInten rankOldAndNew   movieCd movieNm      openDt  \
# 1      2     2          0           OLD  20192399    1917  2020-02-19
# 11     2     2          0           OLD  20192399    1917  2020-02-19
# 21     2     2          0           OLD  20192399    1917  2020-02-19
# 31     2     2          0           OLD  20192399    1917  2020-02-19
# 41     2     2          0           OLD  20192399    1917  2020-02-19
#
#      salesAmt  salesShare  salesInten  salesChange    salesAcc  audiCnt  \
# 1    40711640        20.8      716600          1.8  6197474320     4775
# 11   39995040        20.4   -72101620        -64.3  6156762680     4671
# 21  112096660        21.7   -22267320        -16.6  6116767640    12275
# 31  134363980        22.2    68072480        102.7  6004670980    14638
# 41   66291500        20.1    13509060         25.6  5870307000     7247
#
#     audiInten  audiChange  audiAcc  scrnCnt  showCnt  targetDt
# 1         104         2.2   676039      489     1024  20200324
# 11      -7604       -61.9   671264      469     1009  20200323
# 21      -2363       -16.1   666593      543     1359  20200322
# 31       7391       102.0   654318      546     1372  20200321
# 41       1169        19.2   639680      501     1073  20200320

# %%
mpl.rc('font', family='NanumBarunGothic') #한글 폰트 설정
plt.plot([str(x) for x in temp1['targetDt']], temp1['salesAmt'])
# loc: key값, iloc: index값
# 행은 6번째
plt.title('"{}"의 일별 매출액(salesAmt) 선 그래프'.format(temp1.iloc[0,5]))
plt.xlabel('날짜')
plt.ylabel('매출액')
# 날짜 구십도로 표현
plt.xticks(fontsize=9, rotation=90)
plt.show()

# %%
# 그룹으로 묶어서 합계 계산
temp = df.groupby('movieNm').sum()
temp
# Out:
#                       rnum  rank  rankInten    movieCd    salesAmt  \
# movieNm
# 1917                    68    68          0  605771970  3567341220
# 걸즈 앤 판처 최종장             10    10          0   20196828     8802000
# 그린 북                    10    10         60   20184574     2663500
# 그링고                     29    29         15   60616587    19781500
# 기생충                     66    66          1  161470256    49923870
# 남산의 부장들                 10    10          1   20180939     3080960
# 다크 워터스                  34    34         -1  282867074   937941760
# 더 보이 2: 돌아온 브람스         64    64         -3  161637448   180600000
# 메멘토                     58    58          0  140071666    44831000
# 분노의 질주: 더 익스트림          39    39          0   80670168    42935500
# 세인트 아가타                 42    42         57  121230576    97909100
# 수퍼 소닉                    9     9          0   20184891     3124000
# 쉰들러 리스트                 18    18          0   39880232     6207500
# 스타 이즈 본                 99    99          8  282527322   137237980
# 시원찮은 그녀를 위한 육성방법 피날레    44    44         21  101021700    53030060
# 신의 한 수: 귀수편             18    18          0   40362868    16440000
# 어바웃 타임                 151   151         10  342302276   137251500
# 엠마                      10    10          1   20204546     3405000
# 울프 콜                    38    38         42  121145184   138296460
# 인비저블맨                   28    28          0  565595576  4409430520
# 작은 아씨들                 159   159         -2  605767200  1168070080
# 장마                      10    10          7   20205525     4074000
# 정직한 후보                 135   135         -1  605799630  1345636650
# 젠틀맨                    102   102          3  282709364   561505250
# 조조 래빗                   75    75          3  181776510    67299860
# 지푸라기라도 잡고 싶은 짐승들       114   114         -4  605428860  2084528640
# 찬실이는 복도 많지               9     9          6   20192751     5683880
# 클로젯                     58    58         -2  141277129    90527280
# 트루먼 쇼                   16    16          0   39960462     9071500
# 하이, 젝시                  14    14          0   40387822    19158000
# 해리포터와 아즈카반의 죄수         113   113          0  300608970   490857500
#
#                       salesShare  salesInten  salesChange      salesAcc  \
# movieNm
# 1917                       589.8  -478931440        107.0  144725327670
# 걸즈 앤 판처 최종장                  2.3     8802000        100.0       8802000
# 그린 북                         1.0     2603500       4339.2    3689881360
# 그링고                          4.8     4789000        336.1      94843500
# 기생충                          7.3   -21251220       -134.3  697764380070
# 남산의 부장들                      0.5    -5089720        -62.3   41209709750
# 다크 워터스                     209.2    19967840        154.5    8397152280
# 더 보이 2: 돌아온 브람스             26.2    18686500        135.2    1054658000
# 메멘토                         10.1     4223000         66.4    1150412600
# 분노의 질주: 더 익스트림              10.1    11855500        148.5  120024194392
# 세인트 아가타                     28.2     6196660      31180.6     417762380
# 수퍼 소닉                        0.5   -13047160        -80.7     893288390
# 쉰들러 리스트                      2.2     3109000        100.3     104168580
# 스타 이즈 본                     33.7      -81400        100.9   60964750440
# 시원찮은 그녀를 위한 육성방법 피날레         9.6    22913160        803.7     303497140
# 신의 한 수: 귀수편                  2.5    16440000        200.0   36951952100
# 어바웃 타임                      26.3    14020000        320.8  427979827600
# 엠마                           0.7     1139000         50.3      24857500
# 울프 콜                        21.5    15625640      57331.4     561756460
# 인비저블맨                      729.9    43585380        247.8   76864584190
# 작은 아씨들                     187.1  -189658950        -66.6  203580025020
# 장마                           0.3     1458000         55.7      11139000
# 정직한 후보                     211.6  -376498700       -106.4  370719492410
# 젠틀맨                         70.5    28034200       1771.9    5371455750
# 조조 래빗                        8.7   -11367980        -14.0    8011846380
# 지푸라기라도 잡고 싶은 짐승들           311.8  -632951160        -91.6  142926495250
# 찬실이는 복도 많지                   1.9     2261700         66.1     146076840
# 클로젯                         13.2   -59213980       -159.7   76327182540
# 트루먼 쇼                        4.6     4595000        102.6     228000000
# 하이, 젝시                       3.0   -15076500        -71.6     379716000
# 해리포터와 아즈카반의 죄수              66.4    18198000         36.6  168708689500
#
#                       audiCnt  audiInten  audiChange   audiAcc  scrnCnt  \
# movieNm
# 1917                   393002     -49115        93.5  15757320    16816
# 걸즈 앤 판처 최종장              1030       1030       100.0      1030       11
# 그린 북                      530        518      4316.7    441993      100
# 그링고                      3823       1061       621.3     17115       83
# 기생충                      7418      -2932      -120.7  82265185      832
# 남산의 부장들                   382       -526       -57.9   4748387       94
# 다크 워터스                 107588       2460       138.1    964680     6886
# 더 보이 2: 돌아온 브람스         19783       1982       107.6    118797     1190
# 메멘토                      8924        843        67.1    162035      798
# 분노의 질주: 더 익스트림           4299       1188       148.6  14622920      139
# 세인트 아가타                 11002        742     26204.3     47123     1940
# 수퍼 소닉                     432      -1546       -78.2    113788      112
# 쉰들러 리스트                  1239        620       100.2     13584      237
# 스타 이즈 본                 27241        -22       100.8   7137659     2760
# 시원찮은 그녀를 위한 육성방법 피날레     6448       2815       846.1     35012      293
# 신의 한 수: 귀수편              1644       1644       200.0   4317314       10
# 어바웃 타임                  27064       2744       314.7  58241848     1593
# 엠마                        529        161        43.8      3902       17
# 울프 콜                    16590       1981     64333.6     67863     1903
# 인비저블맨                  504363       5210       192.3   8865199    17466
# 작은 아씨들                 140165     -21032       -66.3  24162304    10618
# 장마                        835        506       153.8      1790        1
# 정직한 후보                 171906     -41377       -61.8  44075999    12184
# 젠틀맨                     69658       3036      2324.7    682748     5183
# 조조 래빗                    8140       -817        23.1    933344      957
# 지푸라기라도 잡고 싶은 짐승들       243563     -68079      -104.1  16488580    14128
# 찬실이는 복도 많지                722        281        63.7     17148       86
# 클로젯                     11933      -6702      -160.8   8841941     1297
# 트루먼 쇼                    1798        915       103.6     27739      208
# 하이, 젝시                   2493      -1462       -63.0     47273      311
# 해리포터와 아즈카반의 죄수          54275       2099         9.6  27167144      660
#
#                       showCnt   targetDt
# movieNm
# 1917                    45974  606008859
# 걸즈 앤 판처 최종장                58   20200312
# 그린 북                      159   20200316
# 그링고                       114   60600930
# 기생충                      1566  161602113
# 남산의 부장들                   135   20200224
# 다크 워터스                  17300  282804445
# 더 보이 2: 돌아온 브람스          2775  161602477
# 메멘토                      1308  141402205
# 분노의 질주: 더 익스트림            522   80801282
# 세인트 아가타                  3346  121201929
# 수퍼 소닉                     129   20200224
# 쉰들러 리스트                   334   40400633
# 스타 이즈 본                  3764  282804445
# 시원찮은 그녀를 위한 육성방법 피날레      436  101001315
# 신의 한 수: 귀수편                11   40400452
# 어바웃 타임                   2512  343405343
# 엠마                         35   20200304
# 울프 콜                     3461  121201845
# 인비저블맨                   51059  565608410
# 작은 아씨들                  21524  606008859
# 장마                          5   20200301
# 정직한 후보                  28863  606008859
# 젠틀맨                     12814  282803881
# 조조 래빗                    1580  181802342
# 지푸라기라도 잡고 싶은 짐승들        39734  606008859
# 찬실이는 복도 많지                131   20200318
# 클로젯                      2152  141401736
# 트루먼 쇼                     323   40400647
# 하이, 젝시                    681   40400449
# 해리포터와 아즈카반의 죄수           3009  303004276

# %%
# 한 달도 몇일 동안 개봉했는지를 알 수 있음
temp = df.groupby('movieNm').count()
temp
# Out:
#                       rnum  rank  rankInten  rankOldAndNew  movieCd  openDt  \
# movieNm
# 1917                    30    30         30             30       30      30
# 걸즈 앤 판처 최종장              1     1          1              1        1       1
# 그린 북                     1     1          1              1        1       1
# 그링고                      3     3          3              3        3       3
# 기생충                      8     8          8              8        8       8
# 남산의 부장들                  1     1          1              1        1       1
# 다크 워터스                  14    14         14             14       14      14
# 더 보이 2: 돌아온 브람스          8     8          8              8        8       8
# 메멘토                      7     7          7              7        7       7
# 분노의 질주: 더 익스트림           4     4          4              4        4       4
# 세인트 아가타                  6     6          6              6        6       6
# 수퍼 소닉                    1     1          1              1        1       1
# 쉰들러 리스트                  2     2          2              2        2       2
# 스타 이즈 본                 14    14         14             14       14      14
# 시원찮은 그녀를 위한 육성방법 피날레     5     5          5              5        5       5
# 신의 한 수: 귀수편              2     2          2              2        2       2
# 어바웃 타임                  17    17         17             17       17      17
# 엠마                       1     1          1              1        1       1
# 울프 콜                     6     6          6              6        6       6
# 인비저블맨                   28    28         28             28       28      28
# 작은 아씨들                  30    30         30             30       30      30
# 장마                       1     1          1              1        1       1
# 정직한 후보                  30    30         30             30       30      30
# 젠틀맨                     14    14         14             14       14      14
# 조조 래빗                    9     9          9              9        9       9
# 지푸라기라도 잡고 싶은 짐승들        30    30         30             30       30      30
# 찬실이는 복도 많지               1     1          1              1        1       1
# 클로젯                      7     7          7              7        7       7
# 트루먼 쇼                    2     2          2              2        2       2
# 하이, 젝시                   2     2          2              2        2       2
# 해리포터와 아즈카반의 죄수          15    15         15             15       15      15
#
#                       salesAmt  salesShare  salesInten  salesChange  salesAcc  \
# movieNm
# 1917                        30          30          30           30        30
# 걸즈 앤 판처 최종장                  1           1           1            1         1
# 그린 북                         1           1           1            1         1
# 그링고                          3           3           3            3         3
# 기생충                          8           8           8            8         8
# 남산의 부장들                      1           1           1            1         1
# 다크 워터스                      14          14          14           14        14
# 더 보이 2: 돌아온 브람스              8           8           8            8         8
# 메멘토                          7           7           7            7         7
# 분노의 질주: 더 익스트림               4           4           4            4         4
# 세인트 아가타                      6           6           6            6         6
# 수퍼 소닉                        1           1           1            1         1
# 쉰들러 리스트                      2           2           2            2         2
# 스타 이즈 본                     14          14          14           14        14
# 시원찮은 그녀를 위한 육성방법 피날레         5           5           5            5         5
# 신의 한 수: 귀수편                  2           2           2            2         2
# 어바웃 타임                      17          17          17           17        17
# 엠마                           1           1           1            1         1
# 울프 콜                         6           6           6            6         6
# 인비저블맨                       28          28          28           28        28
# 작은 아씨들                      30          30          30           30        30
# 장마                           1           1           1            1         1
# 정직한 후보                      30          30          30           30        30
# 젠틀맨                         14          14          14           14        14
# 조조 래빗                        9           9           9            9         9
# 지푸라기라도 잡고 싶은 짐승들            30          30          30           30        30
# 찬실이는 복도 많지                   1           1           1            1         1
# 클로젯                          7           7           7            7         7
# 트루먼 쇼                        2           2           2            2         2
# 하이, 젝시                       2           2           2            2         2
# 해리포터와 아즈카반의 죄수              15          15          15           15        15
#
#                       audiCnt  audiInten  audiChange  audiAcc  scrnCnt  \
# movieNm
# 1917                       30         30          30       30       30
# 걸즈 앤 판처 최종장                 1          1           1        1        1
# 그린 북                        1          1           1        1        1
# 그링고                         3          3           3        3        3
# 기생충                         8          8           8        8        8
# 남산의 부장들                     1          1           1        1        1
# 다크 워터스                     14         14          14       14       14
# 더 보이 2: 돌아온 브람스             8          8           8        8        8
# 메멘토                         7          7           7        7        7
# 분노의 질주: 더 익스트림              4          4           4        4        4
# 세인트 아가타                     6          6           6        6        6
# 수퍼 소닉                       1          1           1        1        1
# 쉰들러 리스트                     2          2           2        2        2
# 스타 이즈 본                    14         14          14       14       14
# 시원찮은 그녀를 위한 육성방법 피날레        5          5           5        5        5
# 신의 한 수: 귀수편                 2          2           2        2        2
# 어바웃 타임                     17         17          17       17       17
# 엠마                          1          1           1        1        1
# 울프 콜                        6          6           6        6        6
# 인비저블맨                      28         28          28       28       28
# 작은 아씨들                     30         30          30       30       30
# 장마                          1          1           1        1        1
# 정직한 후보                     30         30          30       30       30
# 젠틀맨                        14         14          14       14       14
# 조조 래빗                       9          9           9        9        9
# 지푸라기라도 잡고 싶은 짐승들           30         30          30       30       30
# 찬실이는 복도 많지                  1          1           1        1        1
# 클로젯                         7          7           7        7        7
# 트루먼 쇼                       2          2           2        2        2
# 하이, 젝시                      2          2           2        2        2
# 해리포터와 아즈카반의 죄수             15         15          15       15       15
#
#                       showCnt  targetDt
# movieNm
# 1917                       30        30
# 걸즈 앤 판처 최종장                 1         1
# 그린 북                        1         1
# 그링고                         3         3
# 기생충                         8         8
# 남산의 부장들                     1         1
# 다크 워터스                     14        14
# 더 보이 2: 돌아온 브람스             8         8
# 메멘토                         7         7
# 분노의 질주: 더 익스트림              4         4
# 세인트 아가타                     6         6
# 수퍼 소닉                       1         1
# 쉰들러 리스트                     2         2
# 스타 이즈 본                    14        14
# 시원찮은 그녀를 위한 육성방법 피날레        5         5
# 신의 한 수: 귀수편                 2         2
# 어바웃 타임                     17        17
# 엠마                          1         1
# 울프 콜                        6         6
# 인비저블맨                      28        28
# 작은 아씨들                     30        30
# 장마                          1         1
# 정직한 후보                     30        30
# 젠틀맨                        14        14
# 조조 래빗                       9         9
# 지푸라기라도 잡고 싶은 짐승들           30        30
# 찬실이는 복도 많지                  1         1
# 클로젯                         7         7
# 트루먼 쇼                       2         2
# 하이, 젝시                      2         2
# 해리포터와 아즈카반의 죄수             15        15

# %%
mpl.rc('font', family='NanumBarunGothic') #한글 폰트 설정
# inch 단위
plt.figure(figsize=(15, 5))
plt.bar(temp.index, temp['salesAmt']) 
plt.title('영화명(movieNm)별 총 매출액 막대 그래프')
plt.xlabel('영화명')
plt.ylabel('총매출액')
plt.xticks(fontsize=9, rotation=90)
plt.show()

# %%
df = pd.read_csv(r'cinebox.csv',engine='python',encoding='utf-8')
temp = df.groupby('movieNm').sum()
temp.head()
# Out:
#              rnum  rank  rankInten    movieCd    salesAmt  salesShare  \
# movieNm
# 1917           68    68          0  605771970  3567341220       589.8
# 걸즈 앤 판처 최종장    10    10          0   20196828     8802000         2.3
# 그린 북           10    10         60   20184574     2663500         1.0
# 그링고            29    29         15   60616587    19781500         4.8
# 기생충            66    66          1  161470256    49923870         7.3
#
#              salesInten  salesChange      salesAcc  audiCnt  audiInten  \
# movieNm
# 1917         -478931440        107.0  144725327670   393002     -49115
# 걸즈 앤 판처 최종장     8802000        100.0       8802000     1030       1030
# 그린 북            2603500       4339.2    3689881360      530        518
# 그링고             4789000        336.1      94843500     3823       1061
# 기생충           -21251220       -134.3  697764380070     7418      -2932
#
#              audiChange   audiAcc  scrnCnt  showCnt   targetDt
# movieNm
# 1917               93.5  15757320    16816    45974  606008859
# 걸즈 앤 판처 최종장       100.0      1030       11       58   20200312
# 그린 북             4316.7    441993      100      159   20200316
# 그링고               621.3     17115       83      114   60600930
# 기생충              -120.7  82265185      832     1566  161602113

# %%
mpl.rc('font', family='NanumBarunGothic') #한글 폰트 설정
plt.figure(figsize=(10, 5))
plt.scatter(temp['salesAmt'], temp['audiCnt'])
#plt.scatter(temp['salesAmt'], temp['audiAcc']) 
plt.title('총 매출액과 총 관객수 분포도')
plt.xlabel('총매출액')
plt.ylabel('총관객수')
plt.show()

# %%
df = pd.read_csv(r'cinebox.csv',engine='python',encoding='utf-8')
temp = df.groupby('movieNm').sum()
# salesAmt로 정렬
temp = temp.sort_values(by='salesAmt', ascending=0)
temp = temp.iloc[:10]
temp
# Out:
#                   rnum  rank  rankInten    movieCd    salesAmt  salesShare  \
# movieNm
# 인비저블맨               28    28          0  565595576  4409430520       729.9
# 1917                68    68          0  605771970  3567341220       589.8
# 지푸라기라도 잡고 싶은 짐승들   114   114         -4  605428860  2084528640       311.8
# 정직한 후보             135   135         -1  605799630  1345636650       211.6
# 작은 아씨들             159   159         -2  605767200  1168070080       187.1
# 다크 워터스              34    34         -1  282867074   937941760       209.2
# 젠틀맨                102   102          3  282709364   561505250        70.5
# 해리포터와 아즈카반의 죄수     113   113          0  300608970   490857500        66.4
# 더 보이 2: 돌아온 브람스     64    64         -3  161637448   180600000        26.2
# 울프 콜                38    38         42  121145184   138296460        21.5
#
#                   salesInten  salesChange      salesAcc  audiCnt  audiInten  \
# movieNm
# 인비저블맨               43585380        247.8   76864584190   504363       5210
# 1917              -478931440        107.0  144725327670   393002     -49115
# 지푸라기라도 잡고 싶은 짐승들  -632951160        -91.6  142926495250   243563     -68079
# 정직한 후보            -376498700       -106.4  370719492410   171906     -41377
# 작은 아씨들            -189658950        -66.6  203580025020   140165     -21032
# 다크 워터스              19967840        154.5    8397152280   107588       2460
# 젠틀맨                 28034200       1771.9    5371455750    69658       3036
# 해리포터와 아즈카반의 죄수      18198000         36.6  168708689500    54275       2099
# 더 보이 2: 돌아온 브람스     18686500        135.2    1054658000    19783       1982
# 울프 콜                15625640      57331.4     561756460    16590       1981
#
#                   audiChange   audiAcc  scrnCnt  showCnt   targetDt
# movieNm
# 인비저블맨                  192.3   8865199    17466    51059  565608410
# 1917                    93.5  15757320    16816    45974  606008859
# 지푸라기라도 잡고 싶은 짐승들      -104.1  16488580    14128    39734  606008859
# 정직한 후보                 -61.8  44075999    12184    28863  606008859
# 작은 아씨들                 -66.3  24162304    10618    21524  606008859
# 다크 워터스                 138.1    964680     6886    17300  282804445
# 젠틀맨                   2324.7    682748     5183    12814  282803881
# 해리포터와 아즈카반의 죄수           9.6  27167144      660     3009  303004276
# 더 보이 2: 돌아온 브람스        107.6    118797     1190     2775  161602477
# 울프 콜                 64333.6     67863     1903     3461  121201845

# %%
mpl.rc('font', family='NanumBarunGothic') #한글 폰트 설정
mpl.rcParams['font.size'] = 9
plt.figure(figsize=(10, 5))
# autopct: 소수점
plt.pie(temp['salesAmt'], labels=temp.index, autopct='%.1f%%', shadow=True)
plt.title('총 매출액 TOP 10 의 영화명(movieNm) 파이 차트')
plt.show()

# %%
df1 = pd.read_csv(r'cinebox.csv',engine='python',encoding='utf-8')
df2 = pd.read_csv(r'cine.csv',engine='python',encoding='utf-8')
# movieCd를 기준으로 df1,2를 merge
df3 = pd.merge(df1, df2, on='movieCd')
df3
# Out:
#      rnum  rank  rankInten rankOldAndNew   movieCd    movieNm_x      openDt  \
# 0       1     1          0           OLD  20199842        인비저블맨  2020-02-26
# 1       1     1          0           OLD  20199842        인비저블맨  2020-02-26
# 2       1     1          0           OLD  20199842        인비저블맨  2020-02-26
# 3       1     1          0           OLD  20199842        인비저블맨  2020-02-26
# 4       1     1          0           OLD  20199842        인비저블맨  2020-02-26
# ..    ...   ...        ...           ...       ...          ...         ...
# 295     9     9          0           NEW  20181434  신의 한 수: 귀수편  2019-11-07
# 296     7     7          0           OLD  20193911       하이, 젝시  2020-02-19
# 297     7     7          0           OLD  20193911       하이, 젝시  2020-02-19
# 298     9     9          0           OLD  20184891        수퍼 소닉  2020-02-12
# 299    10    10          1           OLD  20180939      남산의 부장들  2020-01-22
#
#       salesAmt  salesShare  salesInten  ...  audiInten  audiChange  audiAcc  \
# 0     43585380        22.3    -5891160  ...       -694       -11.8   504363
# 1     49476540        25.3   -92045660  ...      -9534       -61.8   499153
# 2    141522200        27.4   -16613920  ...      -1937       -11.1   493249
# 3    158136120        26.2    77471380  ...       8457        94.8   477811
# 4     80664740        24.4    22324560  ...       1965        28.3   460436
# ..         ...         ...         ...  ...        ...         ...      ...
# 295    7960000         1.3     7960000  ...        796       100.0  2158233
# 296    8805000         1.4    -1548000  ...       -195       -14.5    24211
# 297   10353000         1.6   -13528500  ...      -1267       -48.5    23062
# 298    3124000         0.5   -13047160  ...      -1546       -78.2   113788
# 299    3080960         0.5    -5089720  ...       -526       -57.9  4748387
#
#      scrnCnt  showCnt  targetDt    movieNm_y  showTm  actors showTypes
# 0        483     1130  20200324        인비저블맨     124       2         2
# 1        500     1206  20200323        인비저블맨     124       2         2
# 2        594     1651  20200322        인비저블맨     124       2         2
# 3        593     1645  20200321        인비저블맨     124       2         2
# 4        554     1400  20200320        인비저블맨     124       2         2
# ..       ...      ...       ...          ...     ...     ...       ...
# 295        4        5  20200225  신의 한 수: 귀수편     106      15         2
# 296      159      331  20200225       하이, 젝시      84       2         1
# 297      152      350  20200224       하이, 젝시      84       2         1
# 298      112      129  20200224        수퍼 소닉      98       4         4
# 299       94      135  20200224      남산의 부장들     113      65         2
#
# [300 rows x 23 columns]

# %%
df3['rankOldAndNew'].replace(['OLD','NEW'],[0,1], inplace=True)
# 위와 같은 의미인 코드
# df3=df3['rankOldAndNew'].replace(['OLD','NEW'],[0,1])
df3
# Out:
#      rnum  rank  rankInten  rankOldAndNew   movieCd    movieNm_x      openDt  \
# 0       1     1          0              0  20199842        인비저블맨  2020-02-26
# 1       1     1          0              0  20199842        인비저블맨  2020-02-26
# 2       1     1          0              0  20199842        인비저블맨  2020-02-26
# 3       1     1          0              0  20199842        인비저블맨  2020-02-26
# 4       1     1          0              0  20199842        인비저블맨  2020-02-26
# ..    ...   ...        ...            ...       ...          ...         ...
# 295     9     9          0              1  20181434  신의 한 수: 귀수편  2019-11-07
# 296     7     7          0              0  20193911       하이, 젝시  2020-02-19
# 297     7     7          0              0  20193911       하이, 젝시  2020-02-19
# 298     9     9          0              0  20184891        수퍼 소닉  2020-02-12
# 299    10    10          1              0  20180939      남산의 부장들  2020-01-22
#
#       salesAmt  salesShare  salesInten  ...  audiInten  audiChange  audiAcc  \
# 0     43585380        22.3    -5891160  ...       -694       -11.8   504363
# 1     49476540        25.3   -92045660  ...      -9534       -61.8   499153
# 2    141522200        27.4   -16613920  ...      -1937       -11.1   493249
# 3    158136120        26.2    77471380  ...       8457        94.8   477811
# 4     80664740        24.4    22324560  ...       1965        28.3   460436
# ..         ...         ...         ...  ...        ...         ...      ...
# 295    7960000         1.3     7960000  ...        796       100.0  2158233
# 296    8805000         1.4    -1548000  ...       -195       -14.5    24211
# 297   10353000         1.6   -13528500  ...      -1267       -48.5    23062
# 298    3124000         0.5   -13047160  ...      -1546       -78.2   113788
# 299    3080960         0.5    -5089720  ...       -526       -57.9  4748387
#
#      scrnCnt  showCnt  targetDt    movieNm_y  showTm  actors showTypes
# 0        483     1130  20200324        인비저블맨     124       2         2
# 1        500     1206  20200323        인비저블맨     124       2         2
# 2        594     1651  20200322        인비저블맨     124       2         2
# 3        593     1645  20200321        인비저블맨     124       2         2
# 4        554     1400  20200320        인비저블맨     124       2         2
# ..       ...      ...       ...          ...     ...     ...       ...
# 295        4        5  20200225  신의 한 수: 귀수편     106      15         2
# 296      159      331  20200225       하이, 젝시      84       2         1
# 297      152      350  20200224       하이, 젝시      84       2         1
# 298      112      129  20200224        수퍼 소닉      98       4         4
# 299       94      135  20200224      남산의 부장들     113      65         2
#
# [300 rows x 23 columns]

# %%
# loc는 컬럼의 이름으로!
# 앞은 행(다 가져옴). 뒤는 열(수치데이터만 뺌)
df3=df3.loc[:,['targetDt','rank','rankOldAndNew','movieCd','salesAmt','audiCnt','showTm','actors','showTypes']]
df3
# Out:
#      targetDt  rank rankOldAndNew   movieCd   salesAmt  audiCnt  showTm  \
# 0    20200324     1           OLD  20199842   43585380     5210     124
# 1    20200323     1           OLD  20199842   49476540     5904     124
# 2    20200322     1           OLD  20199842  141522200    15438     124
# 3    20200321     1           OLD  20199842  158136120    17375     124
# 4    20200320     1           OLD  20199842   80664740     8918     124
# ..        ...   ...           ...       ...        ...      ...     ...
# 295  20200225     9           NEW  20181434    7960000      796     106
# 296  20200225     7           OLD  20193911    8805000     1149      84
# 297  20200224     7           OLD  20193911   10353000     1344      84
# 298  20200224     9           OLD  20184891    3124000      432      98
# 299  20200224    10           OLD  20180939    3080960      382     113
#
#      actors  showTypes
# 0         2          2
# 1         2          2
# 2         2          2
# 3         2          2
# 4         2          2
# ..      ...        ...
# 295      15          2
# 296       2          1
# 297       2          1
# 298       4          4
# 299      65          2
#
# [300 rows x 9 columns]

# %%
# 상관계수, 두 변수간의 연관된 정도를 나타낸다. 두 변수가 동일하면 1, 전혀 다르면 0, 반대방향으로 동일하면 -1
temp = df3.corr()
temp
# Out:
#                targetDt      rank  rankOldAndNew   movieCd  salesAmt  \
# targetDt       1.000000  0.000000      -0.124399 -0.067618 -0.244533
# rank           0.000000  1.000000       0.148556 -0.354299 -0.693222
# rankOldAndNew -0.124399  0.148556       1.000000 -0.186360 -0.072724
# movieCd       -0.067618 -0.354299      -0.186360  1.000000  0.218985
# salesAmt      -0.244533 -0.693222      -0.072724  0.218985  1.000000
# audiCnt       -0.272922 -0.701822      -0.054350  0.220658  0.992005
# showTm         0.134562 -0.048546       0.029749 -0.337366  0.051132
# actors        -0.200644  0.122978      -0.053797  0.114672 -0.126280
# showTypes     -0.047223 -0.107774       0.040441 -0.211711  0.229117
#
#                 audiCnt    showTm    actors  showTypes
# targetDt      -0.272922  0.134562 -0.200644  -0.047223
# rank          -0.701822 -0.048546  0.122978  -0.107774
# rankOldAndNew -0.054350  0.029749 -0.053797   0.040441
# movieCd        0.220658 -0.337366  0.114672  -0.211711
# salesAmt       0.992005  0.051132 -0.126280   0.229117
# audiCnt        1.000000  0.051016 -0.128440   0.212657
# showTm         0.051016  1.000000  0.028504   0.279663
# actors        -0.128440  0.028504  1.000000   0.411493
# showTypes      0.212657  0.279663  0.411493   1.000000

# %%
temp = temp.rename(index={'targetDt': '날짜','rank': '순위','rankOldAndNew': '신규진입여부','movieCd': '영화코드','salesAmt': '매출액','audiCnt': '관객수','showTm': '상영시간','actors': '배우 수','showTypes': '상영형태 수'})
temp = temp.rename(columns={'targetDt': '날짜','rank': '순위','rankOldAndNew': '신규진입여부','movieCd': '영화코드','salesAmt': '매출액','audiCnt': '관객수','showTm': '상영시간','actors': '배우 수','showTypes': '상영형태 수'})
temp
# Out:
#               날짜        순위    신규진입여부      영화코드       매출액       관객수      상영시간  \
# 날짜      1.000000  0.000000 -0.124399 -0.067618 -0.244533 -0.272922  0.134562
# 순위      0.000000  1.000000  0.148556 -0.354299 -0.693222 -0.701822 -0.048546
# 신규진입여부 -0.124399  0.148556  1.000000 -0.186360 -0.072724 -0.054350  0.029749
# 영화코드   -0.067618 -0.354299 -0.186360  1.000000  0.218985  0.220658 -0.337366
# 매출액    -0.244533 -0.693222 -0.072724  0.218985  1.000000  0.992005  0.051132
# 관객수    -0.272922 -0.701822 -0.054350  0.220658  0.992005  1.000000  0.051016
# 상영시간    0.134562 -0.048546  0.029749 -0.337366  0.051132  0.051016  1.000000
# 배우 수   -0.200644  0.122978 -0.053797  0.114672 -0.126280 -0.128440  0.028504
# 상영형태 수 -0.047223 -0.107774  0.040441 -0.211711  0.229117  0.212657  0.279663
#
#             배우 수    상영형태 수
# 날짜     -0.200644 -0.047223
# 순위      0.122978 -0.107774
# 신규진입여부 -0.053797  0.040441
# 영화코드    0.114672 -0.211711
# 매출액    -0.126280  0.229117
# 관객수    -0.128440  0.212657
# 상영시간    0.028504  0.279663
# 배우 수    1.000000  0.411493
# 상영형태 수  0.411493  1.000000

# %%
mpl.rc('font', family='NanumBarunGothic') #한글 폰트 설정
plt.figure(figsize=(10, 10))
plt.imshow(temp, cmap='hot')
# 오른쪽 바, 상관관계가 높을 수록 밝은색
plt.colorbar()
plt.title('영화 박스오피스의 컬럼들간의 상관계수 히트맵')
#plt.xticks(range(9), ['targetDt','rank','rankOldAndNew','movieCd','salesAmt','audiCnt','showTm','actors','showTypes'])
plt.xticks(range(len(temp.columns)), temp.columns)
plt.xticks(fontsize=10, rotation=45)
plt.yticks(range(len(temp.index)), temp.index)
plt.yticks(fontsize=10, rotation=45)
plt.show()

# %%
df = pd.read_csv(r'cinebox.csv',engine='python',encoding='utf-8')
df.head()
# Out:
#    rnum  rank  rankInten rankOldAndNew   movieCd           movieNm  \
# 0     1     1          0           OLD  20199842             인비저블맨
# 1     2     2          0           OLD  20192399              1917
# 2     3     3          0           OLD  20204791           다크 워터스
# 3     4     4          0           OLD  20193321            정직한 후보
# 4     5     5          0           OLD  20180962  지푸라기라도 잡고 싶은 짐승들
#
#        openDt  salesAmt  salesShare  salesInten  salesChange     salesAcc  \
# 0  2020-02-26  43585380        22.3    -5891160        -11.9   4409430520
# 1  2020-02-19  40711640        20.8      716600          1.8   6197474320
# 2  2020-03-11  19967840        10.2      748680          3.9    943203760
# 3  2020-02-12   7572620         3.9     -391480         -4.9  12756431310
# 4  2020-02-19   9365900         4.8      821820          9.6   5331424090
#
#    audiCnt  audiInten  audiChange  audiAcc  scrnCnt  showCnt  targetDt
# 0     5210       -694       -11.8   504363      483     1130  20200324
# 1     4775        104         2.2   676039      489     1024  20200324
# 2     2460        111         4.7   108239      404      790  20200324
# 3     1297        -16        -1.2  1523417      238      390  20200324
# 4     1156        132        12.9   614216      236      374  20200324

# %%
temp1 = df[df['movieNm'] == '인비저블맨']
temp1.head()
# Out:
#     rnum  rank  rankInten rankOldAndNew   movieCd movieNm      openDt  \
# 0      1     1          0           OLD  20199842   인비저블맨  2020-02-26
# 10     1     1          0           OLD  20199842   인비저블맨  2020-02-26
# 20     1     1          0           OLD  20199842   인비저블맨  2020-02-26
# 30     1     1          0           OLD  20199842   인비저블맨  2020-02-26
# 40     1     1          0           OLD  20199842   인비저블맨  2020-02-26
#
#      salesAmt  salesShare  salesInten  salesChange    salesAcc  audiCnt  \
# 0    43585380        22.3    -5891160        -11.9  4409430520     5210
# 10   49476540        25.3   -92045660        -65.0  4365845140     5904
# 20  141522200        27.4   -16613920        -10.5  4316368600    15438
# 30  158136120        26.2    77471380         96.0  4174846400    17375
# 40   80664740        24.4    22324560         38.3  4016710280     8918
#
#     audiInten  audiChange  audiAcc  scrnCnt  showCnt  targetDt
# 0        -694       -11.8   504363      483     1130  20200324
# 10      -9534       -61.8   499153      500     1206  20200323
# 20      -1937       -11.1   493249      594     1651  20200322
# 30       8457        94.8   477811      593     1645  20200321
# 40       1965        28.3   460436      554     1400  20200320

# %%
temp2 = df[df['movieNm'] == '1917']
temp2.head()
# Out:
#     rnum  rank  rankInten rankOldAndNew   movieCd movieNm      openDt  \
# 1      2     2          0           OLD  20192399    1917  2020-02-19
# 11     2     2          0           OLD  20192399    1917  2020-02-19
# 21     2     2          0           OLD  20192399    1917  2020-02-19
# 31     2     2          0           OLD  20192399    1917  2020-02-19
# 41     2     2          0           OLD  20192399    1917  2020-02-19
#
#      salesAmt  salesShare  salesInten  salesChange    salesAcc  audiCnt  \
# 1    40711640        20.8      716600          1.8  6197474320     4775
# 11   39995040        20.4   -72101620        -64.3  6156762680     4671
# 21  112096660        21.7   -22267320        -16.6  6116767640    12275
# 31  134363980        22.2    68072480        102.7  6004670980    14638
# 41   66291500        20.1    13509060         25.6  5870307000     7247
#
#     audiInten  audiChange  audiAcc  scrnCnt  showCnt  targetDt
# 1         104         2.2   676039      489     1024  20200324
# 11      -7604       -61.9   671264      469     1009  20200323
# 21      -2363       -16.1   666593      543     1359  20200322
# 31       7391       102.0   654318      546     1372  20200321
# 41       1169        19.2   639680      501     1073  20200320

# %%
mpl.rc('font', family='NanumBarunGothic') #한글 폰트 설정
fig = plt.figure()
fig.set_size_inches(9.4,4.8)

# 분할해 그리기 시작
# 그래프 위치
axe = fig.add_subplot(1,2,1) #1행(row) 2열(column)중 첫 번째 subplot
axe.plot([str(x) for x in temp1['targetDt']], temp1['salesAmt'],label='엑시트')
axe.set_title('인비저블맨')
axe.set_xlabel('날짜')
axe.set_ylabel('매출액')
for tick in axe.xaxis.get_major_ticks():
    tick.label.set_fontsize(9) 
    tick.label.set_rotation(90)
axe = fig.add_subplot(1,2,2) #1행(row) 2열(column)중 두번째 subplot
axe.plot([str(x) for x in temp2['targetDt']], temp2['salesAmt'],label='유열의 음악앨범')
axe.set_title('1917')
axe.set_xlabel('날짜')
axe.set_ylabel('매출액')
for tick in axe.xaxis.get_major_ticks():
    tick.label.set_fontsize(9) 
    tick.label.set_rotation(90)
plt.suptitle('영화명 "인비저블맨"의 일별 매출액(salesAmt)과 영화명 "1917"의 일별 매출액(salesAmt) 선 그래프')
#분할해 그리기 끝
plt.show()

# %%
# or: 양쪽 상영일 중 하나라도 해당되면 dates에 변수 집어넣음
# set: 중복되는 값 뺌
dates = list(set(temp1['targetDt']) | set(temp2['targetDt']))
dates.sort()
dates
# Out:
# [20200224,
#  20200225,
#  20200226,
#  20200227,
#  20200228,
#  20200229,
#  20200301,
#  20200302,
#  20200303,
#  20200304,
#  20200305,
#  20200306,
#  20200307,
#  20200308,
#  20200309,
#  20200310,
#  20200311,
#  20200312,
#  20200313,
#  20200314,
#  20200315,
#  20200316,
#  20200317,
#  20200318,
#  20200319,
#  20200320,
#  20200321,
#  20200322,
#  20200323,
#  20200324]

# %%
def apply_temp1(date):
    return dates.index(date)
temp1['x'] = temp1['targetDt'].apply(apply_temp1)
temp1.head()
# Out:
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
#     rnum  rank  rankInten rankOldAndNew   movieCd movieNm      openDt  \
# 0      1     1          0           OLD  20199842   인비저블맨  2020-02-26
# 10     1     1          0           OLD  20199842   인비저블맨  2020-02-26
# 20     1     1          0           OLD  20199842   인비저블맨  2020-02-26
# 30     1     1          0           OLD  20199842   인비저블맨  2020-02-26
# 40     1     1          0           OLD  20199842   인비저블맨  2020-02-26
#
#      salesAmt  salesShare  salesInten  salesChange    salesAcc  audiCnt  \
# 0    43585380        22.3    -5891160        -11.9  4409430520     5210
# 10   49476540        25.3   -92045660        -65.0  4365845140     5904
# 20  141522200        27.4   -16613920        -10.5  4316368600    15438
# 30  158136120        26.2    77471380         96.0  4174846400    17375
# 40   80664740        24.4    22324560         38.3  4016710280     8918
#
#     audiInten  audiChange  audiAcc  scrnCnt  showCnt  targetDt   x
# 0        -694       -11.8   504363      483     1130  20200324  29
# 10      -9534       -61.8   499153      500     1206  20200323  28
# 20      -1937       -11.1   493249      594     1651  20200322  27
# 30       8457        94.8   477811      593     1645  20200321  26
# 40       1965        28.3   460436      554     1400  20200320  25
